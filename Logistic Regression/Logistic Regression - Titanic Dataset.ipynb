# %%
from sklearn.linear_model import LogisticRegression
import pandas as pd
import numpy as np

# %%
from math import log, exp
class MyLogisticRegression:
    def __init__(self, learning_rate=0, num_of_iterations=0, reg_factor=0, penalty='l2'):
        self.learning_rate = learning_rate
        self.num_of_iterations = num_of_iterations
        self.min_cost=0
        self.M=0
        self.n=0
        self.coef_= np.zeros(self.n)
        self.intercept_= 0
        self.reg_factor= reg_factor
        self.penalty=penalty
    
    def __hypothesis(self, X, m):
        return 1/(1+exp(-1.0*(m.transpose().dot(X))))
    
    def __cost(self, X, Y, m):
        total_cost=0  #Total cost
        for i in range(self.M):
            x=X[i,:]
            y=Y[i]
            hxi= self.__hypothesis(x,m)
            if(hxi==0 and y==1):
                total_cost+= 10**9
                continue
            elif hxi==1 and y==0:
                total_cost+=10**9
                continue
            elif hxi==0 and y==0:
                continue
            elif hxi==1 and y==1:
                continue
            total_cost+=  (-y*log(hxi))-(1-y)*log(1-hxi)    #Total Cost
        for i in range(len(m)):
            if self.penalty=="l2":
                total_cost+= self.reg_factor*(m[i]**2)
            elif self.penalty=='l1':
                total_cost+= self.reg_factor*(abs(m[i]))
        return total_cost
    
    def __step_gradient(self, X, Y, m):
        slope=np.zeros(X.shape[1])   #slope of tangent  
        for i in range(self.M):
            x=X[i,:]
            y=Y[i]
            slope+=(-1/self.M)*(y-self.__hypothesis(x, m))*x   #slope of tangent
        new_m=m-self.learning_rate*slope
        return new_m
    
    def __gradient_descent(self, points):
        try:
            X=points[0]            #Input vector
            self.M=X.shape[0]      #Total number of datapoints in X
            self.n=X.shape[1]      #Total number of features in X
            Y=points[1]       #Output
            X_n=np.append(X,np.ones(self.M).reshape(-1,1),axis=1)     #n+1 column is 1
            m=np.zeros(self.n+1)   #here m is slope of best fit line
            for i in range(self.num_of_iterations):
                m = self.__step_gradient(X_n, Y, m)
                if i%10==0:
                    print(f"Cost after {i}th iterations is: {self.__cost(X_n, Y, m)}.")
            self.min_cost=self.__cost(X_n, Y, m)
            return m[:-1], m[-1]
        except Exception as e:
            print(e)
            return np.zeros(self.n),0
    
    def fit(self, X, Y):
        self.coef_, self.intercept_ = self.__gradient_descent((X,Y))
        
    def predict(self, X_test):
        val= np.zeros(X_test.shape[0])
        add= X_test*self.coef_
        for j in range(X_test.shape[0]):
            for i in range(X_test.shape[1]):
                val[j]+=add[j][i]
        y_pred= val + self.intercept_
        for i in range(len(y_pred)):
            if y_pred[i]>0.5:
                y_pred[i]= 1
            else:
                y_pred[i]=0
        return y_pred
    
    def score(self, Y_truth, Y_pred):
        from collections import Counter
        dict_Y_truth= dict(Counter(Y_truth))
        dict_Y_pred= dict(Counter(Y_pred))
        accurate=0
        for i in dict_Y_truth:
            if i in dict_Y_pred:
                accurate+=min(dict_Y_truth[i],dict_Y_pred[i])
        coeff= accurate/self.M
        return coeff

# %%
titanic_train=pd.read_csv("training_titanic_x_y_train.csv")
titanic_test=pd.read_csv("test_titanic_x_test.csv")

# %%
df_train=titanic_train.copy()
df_test=titanic_test.copy()

# %%
df_test.head(5)
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       2                     Davies, Master. John Morgan Jr    male   8.0
# 1       1                        Leader, Dr. Alice (Farnham)  female  49.0
# 2       3                            Kilgannon, Mr. Thomas J    male   NaN
# 3       2  Jacobsohn, Mrs. Sidney Samuel (Amy Frances Chr...  female  24.0
# 4       1                          McGough, Mr. James Robert    male  36.0
#
#    SibSp  Parch      Ticket     Fare Cabin Embarked
# 0      1      1  C.A. 33112  36.7500   NaN        S
# 1      0      0       17465  25.9292   D17        S
# 2      0      0       36865   7.7375   NaN        Q
# 3      2      1      243847  27.0000   NaN        S
# 4      0      0    PC 17473  26.2875   E25        S

# %%
df_test.describe(include="all")
# Out:
#             Pclass                       Name   Sex         Age       SibSp  \
# count   223.000000                        223   223  178.000000  223.000000
# unique         NaN                        223     2         NaN         NaN
# top            NaN  de Pelsmaeker, Mr. Alfons  male         NaN         NaN
# freq           NaN                          1   150         NaN         NaN
# mean      2.345291                        NaN   NaN   29.694775    0.506726
# std       0.850047                        NaN   NaN   15.398053    1.169700
# min       1.000000                        NaN   NaN    0.420000    0.000000
# 25%       2.000000                        NaN   NaN   19.250000    0.000000
# 50%       3.000000                        NaN   NaN   27.000000    0.000000
# 75%       3.000000                        NaN   NaN   37.750000    1.000000
# max       3.000000                        NaN   NaN   71.000000    8.000000
#
#              Parch   Ticket        Fare    Cabin Embarked
# count   223.000000      223  223.000000       50      222
# unique         NaN      212         NaN       49        3
# top            NaN  CA 2144         NaN  B58 B60        S
# freq           NaN        3         NaN        2      160
# mean      0.304933      NaN   32.622551      NaN      NaN
# std       0.634108      NaN   61.062047      NaN      NaN
# min       0.000000      NaN    0.000000      NaN      NaN
# 25%       0.000000      NaN    7.879200      NaN      NaN
# 50%       0.000000      NaN   12.475000      NaN      NaN
# 75%       0.000000      NaN   30.035400      NaN      NaN
# max       2.000000      NaN  512.329200      NaN      NaN

# %%
df_train.drop(["Name","Cabin","Ticket"],axis=1,inplace=True)
df_test.drop(["Name","Cabin","Ticket"],axis=1,inplace=True)

# %%
df_train.describe(include='all')
# Out:
#             Pclass   Sex         Age       SibSp       Parch        Fare  \
# count   668.000000   668  536.000000  668.000000  668.000000  668.000000
# unique         NaN     2         NaN         NaN         NaN         NaN
# top            NaN  male         NaN         NaN         NaN         NaN
# freq           NaN   427         NaN         NaN         NaN         NaN
# mean      2.296407   NaN   29.700560    0.528443    0.407186   32.064552
# std       0.831638   NaN   14.240257    1.080327    0.854695   45.320835
# min       1.000000   NaN    0.670000    0.000000    0.000000    0.000000
# 25%       2.000000   NaN   21.000000    0.000000    0.000000    7.925000
# 50%       3.000000   NaN   29.000000    0.000000    0.000000   14.750000
# 75%       3.000000   NaN   38.250000    1.000000    0.000000   31.275000
# max       3.000000   NaN   80.000000    8.000000    6.000000  512.329200
#
#        Embarked    Survived
# count       667  668.000000
# unique        3         NaN
# top           S         NaN
# freq        484         NaN
# mean        NaN    0.402695
# std         NaN    0.490808
# min         NaN    0.000000
# 25%         NaN    0.000000
# 50%         NaN    0.000000
# 75%         NaN    1.000000
# max         NaN    1.000000

# %%
def f(g):
    if g=="male":
        return 0
    else:
        return 1
def f1(g):
    if(g=="S"):
        return 0
    if(g=="C"):
        return 1
    if(g=="Q"):
        return 2

# %%
df_train.Age.fillna(df_train.Age.mean(),inplace=True)
df_train["Sex"]=df_train.Sex.apply(f)
df_train.Embarked.fillna("Q",inplace=True)
df_train["Embarked"] = df_train.Embarked.apply(f1)

df_test.Age.fillna(df_test.Age.mean(),inplace=True)
df_test["Sex"]=df_test.Sex.apply(f)
df_test.Embarked.fillna("Q",inplace=True)
df_test["Embarked"] = df_test.Embarked.apply(f1)

# %%
df_train.head()
# Out:
#    Pclass  Sex       Age  SibSp  Parch    Fare  Embarked  Survived
# 0       2    1  29.00000      1      0  26.000         0         1
# 1       3    0  29.70056      0      0   8.050         0         0
# 2       2    0  39.00000      0      0  26.000         0         0
# 3       3    1  29.00000      0      4  21.075         0         0
# 4       3    0  25.00000      0      0   7.050         0         0

# %%
df_test.head()
# Out:
#    Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0       2    0   8.000000      1      1  36.7500         0
# 1       1    1  49.000000      0      0  25.9292         0
# 2       3    0  29.694775      0      0   7.7375         2
# 3       2    1  24.000000      2      1  27.0000         0
# 4       1    0  36.000000      0      0  26.2875         0

# %%
df_train.describe(include="all")
# Out:
#            Pclass         Sex         Age       SibSp       Parch        Fare  \
# count  668.000000  668.000000  668.000000  668.000000  668.000000  668.000000
# mean     2.296407    0.360778   29.700560    0.528443    0.407186   32.064552
# std      0.831638    0.480586   12.753571    1.080327    0.854695   45.320835
# min      1.000000    0.000000    0.670000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000   23.000000    0.000000    0.000000    7.925000
# 50%      3.000000    0.000000   29.700560    0.000000    0.000000   14.750000
# 75%      3.000000    1.000000   35.000000    1.000000    0.000000   31.275000
# max      3.000000    1.000000   80.000000    8.000000    6.000000  512.329200
#
#          Embarked    Survived
# count  668.000000  668.000000
# mean     0.351796    0.402695
# std      0.617496    0.490808
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      1.000000    1.000000
# max      2.000000    1.000000

# %%
X= df_train.drop("Survived", axis=1)
X_train= X.values
Y_train = df_train.Survived
X_test = df_test.values

# %% [markdown]
# # Logistic Regression

# %%
learning_rate=0.001
num_iterations=2000
clf1= MyLogisticRegression(learning_rate, num_iterations)

# %%
clf1.fit(X_train, Y_train)
# Out:
# Cost after 0th iterations is: 452.57514474602675.
# Cost after 10th iterations is: 426.1146851096128.
# Cost after 20th iterations is: 424.0567408027569.
# Cost after 30th iterations is: 423.67198458817325.
# Cost after 40th iterations is: 423.4614278155816.
# Cost after 50th iterations is: 423.272159047288.
# Cost after 60th iterations is: 423.08638336315244.
# Cost after 70th iterations is: 422.9019308187987.
# Cost after 80th iterations is: 422.7185254286828.
# Cost after 90th iterations is: 422.5361245352978.
# Cost after 100th iterations is: 422.35471443963894.
# Cost after 110th iterations is: 422.1742851078912.
# Cost after 120th iterations is: 421.99482703761856.
# Cost after 130th iterations is: 421.816330869898.
# Cost after 140th iterations is: 421.63878734123574.
# Cost after 150th iterations is: 421.46218727729575.
# Cost after 160th iterations is: 421.28652159169405.
# Cost after 170th iterations is: 421.1117812853722.
# Cost after 180th iterations is: 420.9379574460206.
# Cost after 190th iterations is: 420.7650412475088.
# Cost after 200th iterations is: 420.59302394930273.
# Cost after 210th iterations is: 420.42189689587957.
# Cost after 220th iterations is: 420.25165151614385.
# Cost after 230th iterations is: 420.0822793228375.
# Cost after 240th iterations is: 419.91377191194215.
# Cost after 250th iterations is: 419.7461209620929.
# Cost after 260th iterations is: 419.579318233971.
# Cost after 270th iterations is: 419.41335556971626.
# Cost after 280th iterations is: 419.24822489231747.
# Cost after 290th iterations is: 419.0839182050142.
# Cost after 300th iterations is: 418.9204275906934.
# Cost after 310th iterations is: 418.75774521128665.
# Cost after 320th iterations is: 418.5958633071628.
# Cost after 330th iterations is: 418.43477419652.
# Cost after 340th iterations is: 418.2744702747853.
# Cost after 350th iterations is: 418.11494401400137.
# Cost after 360th iterations is: 417.956187962225.
# Cost after 370th iterations is: 417.7981947429148.
# Cost after 380th iterations is: 417.64095705432845.
# Cost after 390th iterations is: 417.4844676689132.
# Cost after 400th iterations is: 417.3287194327007.
# Cost after 410th iterations is: 417.17370526470165.
# Cost after 420th iterations is: 417.0194181562995.
# Cost after 430th iterations is: 416.8658511706458.
# Cost after 440th iterations is: 416.71299744205777.
# Cost after 450th iterations is: 416.5608501754185.
# Cost after 460th iterations is: 416.40940264557065.
# Cost after 470th iterations is: 416.25864819671966.
# Cost after 480th iterations is: 416.10858024183585.
# Cost after 490th iterations is: 415.9591922620568.
# Cost after 500th iterations is: 415.8104778060907.
# Cost after 510th iterations is: 415.6624304896282.
# Cost after 520th iterations is: 415.51504399474345.
# Cost after 530th iterations is: 415.3683120693103.
# Cost after 540th iterations is: 415.2222285264138.
# Cost after 550th iterations is: 415.07678724376234.
# Cost after 560th iterations is: 414.9319821631059.
# Cost after 570th iterations is: 414.7878072896563.
# Cost after 580th iterations is: 414.6442566915087.
# Cost after 590th iterations is: 414.501324499063.
# Cost after 600th iterations is: 414.3590049044531.
# Cost after 610th iterations is: 414.21729216097583.
# Cost after 620th iterations is: 414.0761805825215.
# Cost after 630th iterations is: 413.93566454300714.
# Cost after 640th iterations is: 413.7957384758199.
# Cost after 650th iterations is: 413.65639687325046.
# Cost after 660th iterations is: 413.51763428594023.
# Cost after 670th iterations is: 413.3794453223258.
# Cost after 680th iterations is: 413.24182464809013.
# Cost after 690th iterations is: 413.1047669856112.
# Cost after 700th iterations is: 412.9682671134222.
# Cost after 710th iterations is: 412.83231986566494.
# Cost after 720th iterations is: 412.6969201315569.
# Cost after 730th iterations is: 412.56206285485337.
# Cost after 740th iterations is: 412.42774303331487.
# Cost after 750th iterations is: 412.29395571818054.
# Cost after 760th iterations is: 412.16069601364507.
# Cost after 770th iterations is: 412.02795907633197.
# Cost after 780th iterations is: 411.8957401147809.
# Cost after 790th iterations is: 411.76403438892993.
# Cost after 800th iterations is: 411.63283720960254.
# Cost after 810th iterations is: 411.5021439380072.
# Cost after 820th iterations is: 411.37194998522557.
# Cost after 830th iterations is: 411.24225081171573.
# Cost after 840th iterations is: 411.11304192681376.
# Cost after 850th iterations is: 410.98431888824194.
# Cost after 860th iterations is: 410.85607730161763.
# Cost after 870th iterations is: 410.72831281996747.
# Cost after 880th iterations is: 410.6010211432436.
# Cost after 890th iterations is: 410.4741980178474.
# Cost after 900th iterations is: 410.3478392361536.
# Cost after 910th iterations is: 410.22194063603564.
# Cost after 920th iterations is: 410.096498100401.
# Cost after 930th iterations is: 409.97150755672527.
# Cost after 940th iterations is: 409.84696497659394.
# Cost after 950th iterations is: 409.7228663752425.
# Cost after 960th iterations is: 409.5992078111047.
# Cost after 970th iterations is: 409.4759853853613.
# Cost after 980th iterations is: 409.3531952415001.
# Cost after 990th iterations is: 409.2308335648651.
# Cost after 1000th iterations is: 409.10889658222584.
# Cost after 1010th iterations is: 408.9873805613364.
# Cost after 1020th iterations is: 408.86628181051066.
# Cost after 1030th iterations is: 408.74559667818716.
# Cost after 1040th iterations is: 408.62532155251387.
# Cost after 1050th iterations is: 408.5054528609216.
# Cost after 1060th iterations is: 408.3859870697102.
# Cost after 1070th iterations is: 408.26692068363656.
# Cost after 1080th iterations is: 408.1482502455036.
# Cost after 1090th iterations is: 408.02997233575485.
# Cost after 1100th iterations is: 407.9120835720752.
# Cost after 1110th iterations is: 407.7945806089893.
# Cost after 1120th iterations is: 407.6774601374686.
# Cost after 1130th iterations is: 407.5607188845407.
# Cost after 1140th iterations is: 407.44435361290147.
# Cost after 1150th iterations is: 407.32836112052905.
# Cost after 1160th iterations is: 407.2127382403063.
# Cost after 1170th iterations is: 407.09748183964297.
# Cost after 1180th iterations is: 406.9825888201016.
# Cost after 1190th iterations is: 406.8680561170283.
# Cost after 1200th iterations is: 406.7538806991857.
# Cost after 1210th iterations is: 406.64005956839213.
# Cost after 1220th iterations is: 406.5265897591603.
# Cost after 1230th iterations is: 406.41346833833944.
# Cost after 1240th iterations is: 406.3006924047657.
# Cost after 1250th iterations is: 406.1882590889137.
# Cost after 1260th iterations is: 406.0761655525472.
# Cost after 1270th iterations is: 405.9644089883774.
# Cost after 1280th iterations is: 405.85298661972786.
# Cost after 1290th iterations is: 405.7418957001921.
# Cost after 1300th iterations is: 405.6311335133063.
# Cost after 1310th iterations is: 405.5206973722183.
# Cost after 1320th iterations is: 405.41058461935904.
# Cost after 1330th iterations is: 405.3007926261263.
# Cost after 1340th iterations is: 405.1913187925577.
# Cost after 1350th iterations is: 405.08216054701785.
# Cost after 1360th iterations is: 404.9733153458862.
# Cost after 1370th iterations is: 404.8647806732441.
# Cost after 1380th iterations is: 404.75655404057227.
# Cost after 1390th iterations is: 404.6486329864407.
# Cost after 1400th iterations is: 404.54101507621584.
# Cost after 1410th iterations is: 404.4336979017536.
# Cost after 1420th iterations is: 404.32667908111245.
# Cost after 1430th iterations is: 404.21995625825997.
# Cost after 1440th iterations is: 404.11352710278186.
# Cost after 1450th iterations is: 404.0073893095985.
# Cost after 1460th iterations is: 403.90154059868155.
# Cost after 1470th iterations is: 403.7959787147735.
# Cost after 1480th iterations is: 403.6907014271129.
# Cost after 1490th iterations is: 403.5857065291587.
# Cost after 1500th iterations is: 403.48099183831965.
# Cost after 1510th iterations is: 403.3765551956863.
# Cost after 1520th iterations is: 403.27239446576414.
# Cost after 1530th iterations is: 403.16850753621475.
# Cost after 1540th iterations is: 403.0648923175908.
# Cost after 1550th iterations is: 402.9615467430823.
# Cost after 1560th iterations is: 402.8584687682628.
# Cost after 1570th iterations is: 402.7556563708335.
# Cost after 1580th iterations is: 402.6531075503795.
# Cost after 1590th iterations is: 402.55082032812015.
# Cost after 1600th iterations is: 402.4487927466657.
# Cost after 1610th iterations is: 402.3470228697772.
# Cost after 1620th iterations is: 402.2455087821271.
# Cost after 1630th iterations is: 402.1442485890632.
# Cost after 1640th iterations is: 402.04324041637744.
# Cost after 1650th iterations is: 401.94248241006983.
# Cost after 1660th iterations is: 401.84197273612654.
# Cost after 1670th iterations is: 401.7417095802886.
# Cost after 1680th iterations is: 401.6416911478328.
# Cost after 1690th iterations is: 401.5419156633451.
# Cost after 1700th iterations is: 401.4423813705074.
# Cost after 1710th iterations is: 401.34308653188015.
# Cost after 1720th iterations is: 401.24402942868414.
# Cost after 1730th iterations is: 401.14520836059535.
# Cost after 1740th iterations is: 401.0466216455304.
# Cost after 1750th iterations is: 400.94826761944296.
# Cost after 1760th iterations is: 400.8501446361155.
# Cost after 1770th iterations is: 400.75225106696286.
# Cost after 1780th iterations is: 400.654585300825.
# Cost after 1790th iterations is: 400.55714574377316.
# Cost after 1800th iterations is: 400.4599308189138.
# Cost after 1810th iterations is: 400.3629389661929.
# Cost after 1820th iterations is: 400.26616864220824.
# Cost after 1830th iterations is: 400.1696183200148.
# Cost after 1840th iterations is: 400.0732864889431.
# Cost after 1850th iterations is: 399.9771716544069.
# Cost after 1860th iterations is: 399.8812723377285.
# Cost after 1870th iterations is: 399.78558707595136.
# Cost after 1880th iterations is: 399.69011442166413.
# Cost after 1890th iterations is: 399.59485294282155.
# Cost after 1900th iterations is: 399.4998012225706.
# Cost after 1910th iterations is: 399.404957859077.
# Cost after 1920th iterations is: 399.31032146535415.
# Cost after 1930th iterations is: 399.21589066909365.
# Cost after 1940th iterations is: 399.12166411249825.
# Cost after 1950th iterations is: 399.02764045211546.
# Cost after 1960th iterations is: 398.9338183586762.
# Cost after 1970th iterations is: 398.84019651692813.
# Cost after 1980th iterations is: 398.7467736254825.
# Cost after 1990th iterations is: 398.6535483966493.

# %%
clf1.coef_, clf1.intercept_
# Out:
# (array([-0.14911568,  0.20696401, -0.0183334 , -0.08692162, -0.00270161,
#          0.01333052,  0.05179308]), -0.0005973472402324196)

# %%
y_test_pred= clf1.predict(X_test)
y_train_pred= clf1.predict(X_train)

# %%
print("Train Score: ", score(Y_train, y_train_pred))
# Out:
# Train Score:  0.6811377245508982

# %% [markdown]
# # Sklearn Logistic Regression

# %%
clf2 = LogisticRegression(C=1.0)

# %%
clf2.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
clf2.coef_
# Out:
# array([[-0.95095323,  2.53688304, -0.03343033, -0.2865677 , -0.13233378,
#          0.00272943,  0.24559222]])

# %%
clf2.intercept_
# Out:
# array([1.77884482])

# %%
y_test_pred_skl= clf2.predict(X_test)
y_train_pred_skl= clf2.predict(X_train)

# %%
print("Train Score: ", clf2.score(X_train, Y_train))
# Out:
# Train Score:  0.7919161676646707

# %%
#Number of correct predictions with respect to sklearn logistic regression
np.sum(y_test_pred==y_test_pred_skl)/len(y_test_pred)
# Out:
# 0.7174887892376681

# %% [markdown]
# # Saving Predictions to CSV file

# %%
np.savetxt("prediction_titanic.csv",y_train_pred_skl,delimiter=",",fmt="%.5f")
